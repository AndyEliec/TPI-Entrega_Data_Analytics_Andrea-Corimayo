# %% [markdown]
# <p align="center">
#   Pre-Entrega de Proyecto
# </p>
#
# ---
#
# Alumna: Andrea Corimayo
#
# ---

# %% [markdown]
# # Etapa 1: Recopilación y Preparación de Datos

# %% [markdown]
# **1. Crear un documento en Google Colaboratory y cargar los sets de datos como DataFrames.**

# %% [markdown]
# Importacion de librerias *pandas* y *numpy*:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Conectar a mi unidad de drive:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Verificacion cuales son los archivos que se encuentran guardados mi unidad en la carpeta *datasets*:

# %%
import os
archivos_disponibles = os.listdir("/content/drive/MyDrive/datasets")

print (archivos_disponibles)
# Out:
# ['users.csv', 'reviews.csv', 'hotels.csv', 'Kaggle_users.xlsx', 'ventas.json', 'ventas.sqlite', 'ventas.csv', 'clientes.csv', 'marketing.csv', 'ventas_export_sin_index.csv', 'ventas_export.xlsx', 'ventas_export.json', 'clase 5', 'ventas_clean.csv', 'clientes_clean.csv', 'marketing_clean.csv']

# %% [markdown]
# Realice un bucle *for*  y la condicion *if_else* para verificar si los archivos "ventas.csv" , "clientes.csv" , "marketing.csv" se encuentran estan en la carpeta *datasets*:

# %%
datasets = ["ventas.csv" , "clientes.csv" , "marketing.csv"]

for dataset in datasets:
  if dataset in archivos_disponibles:
    print (f"{dataset} esta disponible")
  else:
    print (f"{dataset} no esta disponible")
# Out:
# ventas.csv esta disponible
# clientes.csv esta disponible
# marketing.csv esta disponible

# %% [markdown]
# Defini las rutas de los datasets:

# %%
ruta_ventas = "/content/drive/MyDrive/datasets/ventas.csv"
ruta_clientes = "/content/drive/MyDrive/datasets/clientes.csv"
ruta_marketing = "/content/drive/MyDrive/datasets/marketing.csv"

# %% [markdown]
# Carga los CSV como Dataframes:

# %%
ventas = pd.read_csv(ruta_ventas)
clientes = pd.read_csv(ruta_clientes)
marketing = pd.read_csv(ruta_marketing)

# %% [markdown]
# Validacion de formas para comprobar que se cargaron correctamente.

# %%
print("ventas.shape ->", ventas.shape)
print("clientes.shape ->", clientes.shape)
print("marketing.shape ->", marketing.shape)
# Out:
# ventas.shape -> (3035, 6)
# clientes.shape -> (567, 5)
# marketing.shape -> (90, 6)

# %% [markdown]
# Mostrar las primeras 4 filas de cada data set, para revisar la estructura de las columnas:

# %%
print("ventas.csv: ")
display(ventas.head(4))
print()
print("clientes.csv: ")
display(clientes.head(4))
print()
print("marketing.csv: ")
display(marketing.head(4))
# Out:
# ventas.csv:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# clientes.csv:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# marketing.csv:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024

# %% [markdown]
# **4. Introducción a Pandas: realizar un análisis exploratorio inicial de los DataFrames.**

# %% [markdown]
# La siguiente funsion *exploracion_datos* analisa los datos de cada archivo:

# %%
def exploracion_datos(df, nombre):
    print(f"=== {nombre} ===")

    print("Dimensiones (filas, columnas): ", df.shape)
    print("-"*100)

    print("\nNombres de las columnas: ", list(df.columns))
    print("-"*100)

    print("Tipo de datos:")
    print(df.dtypes)
    print("-"*100)

    print("\nNulos por columna:")
    print(df.isna().sum())
    print("-"*100)

    print("\nPrimeras filas:")
    display(df.head(5))
    print("-"*100)

    print("\nDescribe (numérico):")
    display(df.describe(include='number'))
    print("-"*100)

    print("\nValores Duplicados: ", df.duplicated().sum())

# %%
exploracion_datos(ventas, "VENTAS (inicial)")
# Out:
# === VENTAS (inicial) ===
# Dimensiones (filas, columnas):  (3035, 6)
# ----------------------------------------------------------------------------------------------------
#
# Nombres de las columnas:  ['id_venta', 'producto', 'precio', 'cantidad', 'fecha_venta', 'categoria']
# ----------------------------------------------------------------------------------------------------
# Tipo de datos:
# id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
# ----------------------------------------------------------------------------------------------------
#
# Nulos por columna:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
# ----------------------------------------------------------------------------------------------------
#
# Primeras filas:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
# ----------------------------------------------------------------------------------------------------
#
# Describe (numérico):
#           id_venta     cantidad
# count  3035.000000  3033.000000
# mean   1499.851400     6.496538
# std     866.465379     3.457250
# min       1.000000     1.000000
# 25%     748.500000     3.000000
# 50%    1502.000000     7.000000
# 75%    2249.500000     9.000000
# max    3000.000000    12.000000
# ----------------------------------------------------------------------------------------------------
#
# Valores Duplicados:  35

# %%
exploracion_datos(clientes, "CLIENTES (inicial)")
# Out:
# === CLIENTES (inicial) ===
# Dimensiones (filas, columnas):  (567, 5)
# ----------------------------------------------------------------------------------------------------
#
# Nombres de las columnas:  ['id_cliente', 'nombre', 'edad', 'ciudad', 'ingresos']
# ----------------------------------------------------------------------------------------------------
# Tipo de datos:
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
# ----------------------------------------------------------------------------------------------------
#
# Nulos por columna:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
# ----------------------------------------------------------------------------------------------------
#
# Primeras filas:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65
# ----------------------------------------------------------------------------------------------------
#
# Describe (numérico):
#        id_cliente        edad      ingresos
# count  567.000000  567.000000    567.000000
# mean   284.000000   37.940035  34668.739012
# std    163.823075   10.202885  12974.531446
# min      1.000000   20.000000    170.290000
# 25%    142.500000   30.000000  26015.240000
# 50%    284.000000   37.000000  35066.830000
# 75%    425.500000   43.000000  42457.100000
# max    567.000000   81.000000  88053.010000
# ----------------------------------------------------------------------------------------------------
#
# Valores Duplicados:  0

# %%
exploracion_datos(marketing, "MARKETING (inicial)")
# Out:
# === MARKETING (inicial) ===
# Dimensiones (filas, columnas):  (90, 6)
# ----------------------------------------------------------------------------------------------------
#
# Nombres de las columnas:  ['id_campanha', 'producto', 'canal', 'costo', 'fecha_inicio', 'fecha_fin']
# ----------------------------------------------------------------------------------------------------
# Tipo de datos:
# id_campanha       int64
# producto         object
# canal            object
# costo           float64
# fecha_inicio     object
# fecha_fin        object
# dtype: object
# ----------------------------------------------------------------------------------------------------
#
# Nulos por columna:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64
# ----------------------------------------------------------------------------------------------------
#
# Primeras filas:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58         Alfombra  Email   4.25   31/03/2024  05/05/2024
# ----------------------------------------------------------------------------------------------------
#
# Describe (numérico):
#        id_campanha      costo
# count    90.000000  90.000000
# mean     45.500000   4.928667
# std      26.124701   0.947750
# min       1.000000   2.950000
# 25%      23.250000   4.372500
# 50%      45.500000   4.900000
# 75%      67.750000   5.562500
# max      90.000000   7.390000
# ----------------------------------------------------------------------------------------------------
#
# Valores Duplicados:  0

# %% [markdown]
# **5. Calidad de Datos: Identificar valores nulos y duplicados en los conjuntos de datos. Documentar el estado inicial de los datos.**

# %% [markdown]
# Esta función analiza un DataFrame existente (df) y muestra:
#  * La cantidad de valores nulos por columna.
#  * El total de filas completamente duplicadas.
#  * Si se especifica una columna clave, los valores más repetidos de esa clave.

# %%
def calidad(df, nombre, clave=None):
    print(f"=== {nombre} ===")
    print("-"*100)

    print("\nNulos por columna:")
    display(df.isna().sum().to_frame("nulos"))
    print("-"*100)

    dup_rows = df.duplicated(keep=False).sum()
    print("Filas duplicadas (exactas):", dup_rows)
    print("-"*100)

    if clave and clave in df.columns:
        dup_key = df[clave].duplicated(keep=False).sum()
        print(f"Duplicados por clave '{clave}':", dup_key)

        if dup_key > 0:
            duplicados_ordenados = (
                df[df[clave].duplicated(keep=False)][clave]
                .value_counts()
                .sort_values(ascending=False)
            )

            print("\nTop valores duplicados más frecuentes:")
            display(duplicados_ordenados.head(10))
        else:
          print(f"No se encontraron duplicados en la clave '{clave}'.")
    else:
        if clave:
            print(f"La clave '{clave}' no existe en el DataFrame.")
        else:
            print("No se indicó una clave para analizar duplicados por columna.")

# %% [markdown]
# Ejecucion de la funcion calidad en *Ventas*:

# %%
calidad(ventas, "VENTAS", clave="id_venta")
# Out:
# === VENTAS ===
# ----------------------------------------------------------------------------------------------------
#
# Nulos por columna:
#              nulos
# id_venta         0
# producto         0
# precio           2
# cantidad         2
# fecha_venta      0
# categoria        0
# ----------------------------------------------------------------------------------------------------
# Filas duplicadas (exactas): 70
# ----------------------------------------------------------------------------------------------------
# Duplicados por clave 'id_venta': 70
#
# Top valores duplicados más frecuentes:
# id_venta
# 56      2
# 421     2
# 424     2
# 1868    2
# 2545    2
# 2778    2
# 145     2
# 300     2
# 439     2
# 906     2
# Name: count, dtype: int64

# %% [markdown]
# # Etapa 2: Preprocesamiento y Limpieza de Datos

# %% [markdown]
# **1- Limpieza de Datos: Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados. Documentar el proceso y los resultados.**

# %% [markdown]
# Crear copia de los archivos para no modificar los originales:

# %%
ventas_clean = ventas.copy()
clientes_clean = clientes.copy()
marketing_clean = marketing.copy()

# %% [markdown]
# Elimina filas duplicadas:

# %%
ventas_clean = ventas_clean.drop_duplicates()
clientes_clean = clientes_clean.drop_duplicates()
marketing_clean = marketing_clean.drop_duplicates()

# %% [markdown]
# Ejecucion de la funcion calidad, con el archivo Ventas:

# %%
calidad(ventas_clean, "VENTAS CLEAN", clave="id_venta")
# Out:
# === VENTAS CLEAN ===
# ----------------------------------------------------------------------------------------------------
#
# Nulos por columna:
#              nulos
# id_venta         0
# producto         0
# precio           2
# cantidad         2
# fecha_venta      0
# categoria        0
# ----------------------------------------------------------------------------------------------------
# Filas duplicadas (exactas): 0
# ----------------------------------------------------------------------------------------------------
# Duplicados por clave 'id_venta': 0
# No se encontraron duplicados en la clave 'id_venta'.

# %% [markdown]
# Función para limpiar texto en columnas tipo string:

# %%
def normalizar_texto(df):
    for col in df.select_dtypes(include="object").columns:

        df[col] = (
            df[col]
            .astype(str)

            .str.strip()

            .str.replace(r"[\u200b\t\r\n]", "", regex=True)

            .str.replace(" +", " ", regex=True)

            .str.title()
        )

    return df

# %% [markdown]
# Normalizar fechas

# %%
for df in [ventas_clean, clientes_clean, marketing_clean]:
    for col in df.columns:
        if "fecha" in col.lower():
            df[col] = pd.to_datetime(df[col], errors="coerce", dayfirst=True)

# %% [markdown]
# Mostramos los tipo de datos de cada archivo, para verificar que las columnas de fechas estan nomalizadas:

# %%
print("Tipos de datos de Ventas:")
print(ventas_clean.dtypes)
print("")
print("Tipos de datos de Clientes:")
print(clientes_clean.dtypes)
print("")
print("Tipos de datos de Marketing:")
print(marketing_clean.dtypes)
# Out:
# Tipos de datos de Ventas:
# id_venta                int64
# producto               object
# precio                 object
# cantidad              float64
# fecha_venta    datetime64[ns]
# categoria              object
# dtype: object
#
# Tipos de datos de Clientes:
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
#
# Tipos de datos de Marketing:
# id_campanha              int64
# producto                object
# canal                   object
# costo                  float64
# fecha_inicio    datetime64[ns]
# fecha_fin       datetime64[ns]
# dtype: object

# %% [markdown]
# Normalizacion de texto:

# %%
ventas_clean = normalizar_texto(ventas_clean)
clientes_clean = normalizar_texto(clientes_clean)
marketing_clean = normalizar_texto(marketing_clean)

# %% [markdown]
# Visualizar la normalizacion de los textos:

# %%
print("Ventas con texto normalizado:")
print(ventas_clean.head(10))
print("")
print("Clientes con texto normalizado:: ")
print(clientes_clean.head(10))
print("")
print("Marketing con texto normalizado:: ")
print(marketing_clean.head(10))
# Out:
# Ventas con texto normalizado:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   $69.94       5.0  2024-01-02
# 1       811    Lámpara De Mesa  $105.10       5.0  2024-01-02
# 2      1156           Secadora   $97.96       3.0  2024-01-02
# 3      1372           Heladera  $114.35       8.0  2024-01-02
# 4      1546           Secadora  $106.21       4.0  2024-01-02
# 5      1697    Horno Eléctrico   $35.35       9.0  2024-01-02
# 6      1710   Plancha De Vapor   $65.43       2.0  2024-01-02
# 7      2959          Proyector   $88.17       9.0  2024-01-02
# 8       318  Rincón De Plantas   $79.86      11.0  2024-01-03
# 9       419         Candelabro   $66.11       8.0  2024-01-03
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
# 5  Electrodomésticos
# 6  Electrodomésticos
# 7        Electrónica
# 8         Decoración
# 9         Decoración
#
# Clientes con texto normalizado::
#    id_cliente               nombre  edad                 ciudad  ingresos
# 0           1      Aloysia Screase    44          Mar Del Plata  42294.68
# 1           2  Kristina Scaplehorn    25                Posadas  24735.04
# 2           3       Filip Castagne    50            Resistencia  35744.85
# 3           4          Liuka Luard    39           Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28                Rosario  28245.65
# 5           6        Patrick Earle    34  San Miguel De Tucumán  62763.31
# 6           7           Etan Deeth    35            Resistencia  37489.71
# 7           8       Booth Bielfelt    40                Córdoba  35255.94
# 8           9         Shirl Labone    29                Rosario  27592.08
# 9          10      Andy Mendenhall    52                Rosario  37153.94
#
# Marketing con texto normalizado::
#    id_campanha             producto  canal  costo fecha_inicio  fecha_fin
# 0           74      Adorno De Pared     Tv   4.81   2024-03-20 2024-05-03
# 1           12               Tablet   Rrss   3.40   2024-03-26 2024-05-13
# 2           32      Lámpara De Mesa  Email   5.54   2024-03-28 2024-04-20
# 3           21           Smartphone   Rrss   6.37   2024-03-29 2024-05-16
# 4           58             Alfombra  Email   4.25   2024-03-31 2024-05-05
# 5           85           Smartwatch     Tv   5.07   2024-04-01 2024-05-05
# 6           36     Plancha De Vapor  Email   5.41   2024-04-02 2024-06-01
# 7           57             Batidora  Email   4.48   2024-04-10 2024-06-08
# 8           44      Adorno De Pared  Email   5.08   2024-04-13 2024-05-10
# 9           84  Parlantes Bluetooth     Tv   4.42   2024-04-17 2024-05-05

# %% [markdown]
# Normalización de valores numéricos:

# %%
if "precio" in ventas_clean.columns:
    ventas_clean["precio"] = (
        ventas_clean["precio"]
        .astype(str)
        .str.replace("$", "", regex=False)
        .str.replace(",", "", regex=False)
        .str.strip()
    )
    ventas_clean["precio"] = pd.to_numeric(ventas_clean["precio"], errors="coerce")

# %% [markdown]
# Mostramos los tipo de datos de ventas, para verificar que las columna Precio tenga valores nomalizados:

# %%
print(ventas_clean.dtypes)
print("")
print("Ventas con columna cantidad normalizado:")
print(ventas_clean.head(10))
print("")
# Out:
# id_venta                int64
# producto               object
# precio                float64
# cantidad              float64
# fecha_venta    datetime64[ns]
# categoria              object
# dtype: object
#
# Ventas con columna cantidad normalizado:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   69.94       5.0  2024-01-02
# 1       811    Lámpara De Mesa  105.10       5.0  2024-01-02
# 2      1156           Secadora   97.96       3.0  2024-01-02
# 3      1372           Heladera  114.35       8.0  2024-01-02
# 4      1546           Secadora  106.21       4.0  2024-01-02
# 5      1697    Horno Eléctrico   35.35       9.0  2024-01-02
# 6      1710   Plancha De Vapor   65.43       2.0  2024-01-02
# 7      2959          Proyector   88.17       9.0  2024-01-02
# 8       318  Rincón De Plantas   79.86      11.0  2024-01-03
# 9       419         Candelabro   66.11       8.0  2024-01-03
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
# 5  Electrodomésticos
# 6  Electrodomésticos
# 7        Electrónica
# 8         Decoración
# 9         Decoración

# %% [markdown]
# Mostramos los tipo de datos de clientes, para verificar que las columna Precio tenga valores nomalizados:

# %%
print(clientes_clean.dtypes)
print("")
print("Clientes con columna cantidad normalizado:")
print(clientes_clean.head(10))
print("")
# Out:
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
#
# Clientes con columna cantidad normalizado:
#    id_cliente               nombre  edad                 ciudad  ingresos
# 0           1      Aloysia Screase    44          Mar Del Plata  42294.68
# 1           2  Kristina Scaplehorn    25                Posadas  24735.04
# 2           3       Filip Castagne    50            Resistencia  35744.85
# 3           4          Liuka Luard    39           Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28                Rosario  28245.65
# 5           6        Patrick Earle    34  San Miguel De Tucumán  62763.31
# 6           7           Etan Deeth    35            Resistencia  37489.71
# 7           8       Booth Bielfelt    40                Córdoba  35255.94
# 8           9         Shirl Labone    29                Rosario  27592.08
# 9          10      Andy Mendenhall    52                Rosario  37153.94

# %% [markdown]
# Mostramos los tipo de datos de Marketing, para verificar que las columna Precio tenga valores nomalizados:

# %%
print(marketing_clean.dtypes)
print("")
print("Marketing con columna cantidad normalizado:")
print(marketing_clean.head(10))
print("")
# Out:
# id_campanha              int64
# producto                object
# canal                   object
# costo                  float64
# fecha_inicio    datetime64[ns]
# fecha_fin       datetime64[ns]
# dtype: object
#
# Marketing con columna cantidad normalizado:
#    id_campanha             producto  canal  costo fecha_inicio  fecha_fin
# 0           74      Adorno De Pared     Tv   4.81   2024-03-20 2024-05-03
# 1           12               Tablet   Rrss   3.40   2024-03-26 2024-05-13
# 2           32      Lámpara De Mesa  Email   5.54   2024-03-28 2024-04-20
# 3           21           Smartphone   Rrss   6.37   2024-03-29 2024-05-16
# 4           58             Alfombra  Email   4.25   2024-03-31 2024-05-05
# 5           85           Smartwatch     Tv   5.07   2024-04-01 2024-05-05
# 6           36     Plancha De Vapor  Email   5.41   2024-04-02 2024-06-01
# 7           57             Batidora  Email   4.48   2024-04-10 2024-06-08
# 8           44      Adorno De Pared  Email   5.08   2024-04-13 2024-05-10
# 9           84  Parlantes Bluetooth     Tv   4.42   2024-04-17 2024-05-05

# %% [markdown]
# Aplicar la normalización de texto

# %%
ventas_clean = normalizar_texto(ventas_clean)
clientes_clean = normalizar_texto(clientes_clean)
marketing_clean = normalizar_texto(marketing_clean)

# %% [markdown]
# Mostramos los df luego de normalizar los textos para revisar que queden bien

# %%
print(ventas_clean.head(10))
print(clientes_clean.head(10))
print(marketing_clean.head(10))
# Out:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   69.94       5.0  2024-01-02
# 1       811    Lámpara De Mesa  105.10       5.0  2024-01-02
# 2      1156           Secadora   97.96       3.0  2024-01-02
# 3      1372           Heladera  114.35       8.0  2024-01-02
# 4      1546           Secadora  106.21       4.0  2024-01-02
# 5      1697    Horno Eléctrico   35.35       9.0  2024-01-02
# 6      1710   Plancha De Vapor   65.43       2.0  2024-01-02
# 7      2959          Proyector   88.17       9.0  2024-01-02
# 8       318  Rincón De Plantas   79.86      11.0  2024-01-03
# 9       419         Candelabro   66.11       8.0  2024-01-03
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
# 5  Electrodomésticos
# 6  Electrodomésticos
# 7        Electrónica
# 8         Decoración
# 9         Decoración
#    id_cliente               nombre  edad                 ciudad  ingresos
# 0           1      Aloysia Screase    44          Mar Del Plata  42294.68
# 1           2  Kristina Scaplehorn    25                Posadas  24735.04
# 2           3       Filip Castagne    50            Resistencia  35744.85
# 3           4          Liuka Luard    39           Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28                Rosario  28245.65
# 5           6        Patrick Earle    34  San Miguel De Tucumán  62763.31
# 6           7           Etan Deeth    35            Resistencia  37489.71
# 7           8       Booth Bielfelt    40                Córdoba  35255.94
# 8           9         Shirl Labone    29                Rosario  27592.08
# 9          10      Andy Mendenhall    52                Rosario  37153.94
#    id_campanha             producto  canal  costo fecha_inicio  fecha_fin
# 0           74      Adorno De Pared     Tv   4.81   2024-03-20 2024-05-03
# 1           12               Tablet   Rrss   3.40   2024-03-26 2024-05-13
# 2           32      Lámpara De Mesa  Email   5.54   2024-03-28 2024-04-20
# 3           21           Smartphone   Rrss   6.37   2024-03-29 2024-05-16
# 4           58             Alfombra  Email   4.25   2024-03-31 2024-05-05
# 5           85           Smartwatch     Tv   5.07   2024-04-01 2024-05-05
# 6           36     Plancha De Vapor  Email   5.41   2024-04-02 2024-06-01
# 7           57             Batidora  Email   4.48   2024-04-10 2024-06-08
# 8           44      Adorno De Pared  Email   5.08   2024-04-13 2024-05-10
# 9           84  Parlantes Bluetooth     Tv   4.42   2024-04-17 2024-05-05

# %% [markdown]
# Mostrar el nombre de las columnas, para verficar que este la columna "cantidad":

# %%
print(ventas_clean.columns)
# Out:
# Index(['id_venta', 'producto', 'precio', 'cantidad', 'fecha_venta',
#        'categoria'],
#       dtype='object')

# %%
if "cantidad" in ventas_clean.columns:
    ventas_clean["cantidad"] = pd.to_numeric(
        ventas_clean["cantidad"], errors="coerce"
    ).astype("Int64")

# %%
print(ventas_clean.dtypes)
# Out:
# id_venta                int64
# producto               object
# precio                float64
# cantidad                Int64
# fecha_venta    datetime64[ns]
# categoria              object
# dtype: object

# %% [markdown]
# Guardar los DataFrames limpios como CSV

# %%
ventas_clean.to_csv("/content/drive/MyDrive/datasets/ventas_clean.csv", index=False)
clientes_clean.to_csv("/content/drive/MyDrive/datasets/clientes_clean.csv", index=False)
marketing_clean.to_csv("/content/drive/MyDrive/datasets/marketing_clean.csv", index=False)

print("Archivos guardados: ventas_clean.csv, clientes_clean.csv, marketing_clean.csv")
# Out:
# Archivos guardados: ventas_clean.csv, clientes_clean.csv, marketing_clean.csv

# %% [markdown]
# **2- Transformación de Datos: Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento.**

# %% [markdown]
# La funcion encontrar_columna busca la primera columna cuyo nombre contenga alguno de los patrones dados.
# *  df: DataFrame de pandas.
# *  candidatos: lista de patrones (minúsculas).

# %%
def encontrar_columna(df, candidatos):
    # Recorremos todas las columnas del DataFrame
    for c in df.columns:

        # Convertimos el nombre de la columna a minúsculas
        # Esto se hace para comparar sin importar si está escrito con mayúsculas o minúsculas
        nombre = c.lower()

        # Verificamos si alguna palabra (patrón) de la lista 'candidatos'
        # está contenida dentro del nombre de la columna
        # 'any()' devuelve True apenas encuentra una coincidencia
        if any(p in nombre for p in candidatos):
            # Si encontramos una coincidencia, devolvemos el nombre original de la columna
            return c

    # Si termina el bucle y no se encontró ninguna coincidencia, devolvemos None
    return None

# %% [markdown]
# Detectar la columna de producto:

# %%
prod_col = encontrar_columna(ventas_clean, ["producto", "id_producto", "sku", "articulo", "artículo"])
if prod_col is None:
    raise ValueError("No se encontró columna de producto. Renombrá una columna a 'producto' o similar.")

print(prod_col)
# Out:
# producto

# %% [markdown]
# Calcular ingreso por registro = precio * cantidad

# %%
ventas_perf = (
    ventas_clean
    .assign(
        ingreso = ventas_clean["precio"] * ventas_clean["cantidad"]
    )
)

# %% [markdown]
#  Agregar métricas por producto:

# %%
resumen_prod = (
    ventas_perf
    .groupby(
        by=prod_col,
        dropna=False,
        as_index=False,
        observed=False
    )
    .agg(
        ingreso_total=('ingreso', 'sum'),
        unidades=('cantidad', 'sum'),
        precio_promedio=('precio', 'mean'),
        registros=('ingreso', 'size')
    )
)
resumen_prod = ventas_perf.groupby(by=prod_col).agg(ingreso_total=('ingreso', 'sum'), unidades=('cantidad', 'sum'), precio_promedio=('precio', 'mean'), registros=('ingreso', 'size'))

print(resumen_prod.head(60))
# Out:
#                         ingreso_total  unidades  precio_promedio  registros
# producto
# Adorno De Pared              48093.49       633        76.097800        100
# Alfombra                     44773.06       615        74.098300        100
# Aspiradora                   50085.86       651        77.447400        100
# Auriculares                  74175.58       958        76.302727        143
# Batidora                      50979.2       672        77.537200        100
# Cafetera                     59607.31       765        79.046581        117
# Candelabro                    11128.8       160        74.595417         24
# Consola De Videojuegos       46174.41       623        76.346869         99
# Cortinas                     44865.03       610        73.649900        100
# Cuadro Decorativo             54297.6       726        74.578000        100
# Cámara Digital               45217.96       638        72.010700        100
# Elementos De Cerámica        45411.09       636        71.611515        100
# Espejo Decorativo            46783.31       635        75.663300        100
# Freidora Eléctrica           50155.15       630        78.251300        100
# Heladera                      25736.8       330        74.127708         48
# Horno Eléctrico               49913.9       633        75.688800        100
# Jarrón Decorativo            51130.88       672        74.534000        100
# Laptop                       46179.48       617        75.326200        100
# Lavadora                     48946.44       671        74.953400        100
# Lámpara De Mesa              82276.38      1112        72.720625        176
# Microondas                   72562.89       912        79.176000        135
# Parlantes Bluetooth          47779.46       660        73.583571         99
# Plancha De Vapor             45196.63       632        73.039200        100
# Proyector                     48187.0       626        74.680404         99
# Rincón De Plantas            50456.45       691        74.823861        101
# Secadora                     52115.45       696        73.338900        100
# Smartphone                   54132.44       665        81.398416        101
# Smartwatch                   47836.86       620        75.535800        100
# Tablet                       25856.57       374        71.382586         58
# Televisor                    47038.04       632        73.815300        100

# %% [markdown]
# Calcular percentil 80 de ingreso_total:

# %%
p80_ingreso = resumen_prod["ingreso_total"].quantile(
    q=0.80,                # q indica el percentil deseado (0.80 = 80% de los datos por debajo)
    interpolation="linear"
)

# %% [markdown]
# Filtrar los productos "de alto rendimiento" y ordenarlos:

# %%
ventas_top = (
    resumen_prod
    .query(
        "ingreso_total >= @p80_ingreso",
        engine="python"
    )

    .sort_values(
        by=["ingreso_total", "unidades"],
        ascending=[False, False],
        na_position="last",
        ignore_index=False
    )
)

# %% [markdown]
# Mostrar resultados

# %%
print(f"Columna de producto detectada: {prod_col}")
print(f"Umbral (percentil 80) de ingreso_total: {float(p80_ingreso):,.2f}")
print("Productos de ALTO RENDIMIENTO (top 20% por ingreso):")
display(ventas_top.head(60))
# Out:
# Columna de producto detectada: producto
# Umbral (percentil 80) de ingreso_total: 52,518.85
# Productos de ALTO RENDIMIENTO (top 20% por ingreso):
#                    ingreso_total  unidades  precio_promedio  registros
# producto
# Lámpara De Mesa         82276.38      1112        72.720625        176
# Auriculares             74175.58       958        76.302727        143
# Microondas              72562.89       912        79.176000        135
# Cafetera                59607.31       765        79.046581        117
# Cuadro Decorativo        54297.6       726        74.578000        100
# Smartphone              54132.44       665        81.398416        101

# %% [markdown]
# **3- Agregación: Resumir las ventas por categoría de producto y analizar los ingresos generados.**

# %%
def encontrar_columna(df, candidatos):
    for c in df.columns:
        if any(p in c.lower() for p in candidatos):
            return c
    return None

# %%
# 1) Detectar columna de categoría (acepta variantes)
cat_col = encontrar_columna(ventas_clean, ["categoria", "categoría", "categoria_producto", "rubro"])
if cat_col is None:
    raise ValueError("No se encontró columna de categoría (por ej. 'categoria' o 'rubro').")

# 2) Asegurar columna 'ingreso' (si no existe, crearla)
if "ingreso" not in ventas_clean.columns:
    ventas_cat = ventas_clean.assign(ingreso = ventas_clean["precio"] * ventas_clean["cantidad"])
else:
    ventas_cat = ventas_clean.copy()

# 3) Agregación por categoría con groupby + agg
resumen_cat = (
    ventas_cat
    .groupby(
        by=cat_col,
        dropna=False,
        as_index=False
    )
    .agg(
        ingreso_total=('ingreso', 'sum'),
        unidades=('cantidad', 'sum'),
        ventas=('ingreso', 'size'),
        precio_promedio=('precio', 'mean')
    )
    .sort_values(
        by='ingreso_total',
        ascending=False,
        na_position='last',
        ignore_index=True
    )
)

# 4) Ticket promedio por venta = ingreso_total / ventas
resumen_cat = resumen_cat.assign(
    ticket_promedio_por_venta = resumen_cat['ingreso_total'] / resumen_cat['ventas']
)

print("Columna de categoría detectada:", cat_col)
print("Resumen por categoría (ordenado por ingreso_total):")
display(resumen_cat.head(20))
# Out:
# Columna de categoría detectada: categoria
# Resumen por categoría (ordenado por ingreso_total):
#            categoria  ingreso_total  unidades  ventas  precio_promedio  \
# 0  Electrodomésticos      505299.63      6592    1000         76.52096
# 1        Electrónica       482577.8      6413     999         75.25492
# 2         Decoración      479216.09      6490    1001         74.09800
#
#    ticket_promedio_por_venta
# 0                  505.29963
# 1                 483.060861
# 2                 478.737353

# %% [markdown]
# **4- Integración de Datos: Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.**

# %%
# 1) Intento SIMPLE de detectar una clave común
# ---------------------------
claves_tentativas = [
    "id_cliente", "cliente", "email",
    "id_campaña", "id_campana", "id_campanha",
    "sku", "id_producto", "producto"
]

# Busca la primera clave que exista con el mismo nombre en ambos DataFrames
clave_comun = next(
    (k for k in claves_tentativas if k in ventas_clean.columns and k in marketing_clean.columns),
    None
)

# ---------------------------
# 2) Si NO hay clave exactamente igual en ambos, pedimos definir a mano
# ---------------------------
# Cambiá estos nombres si tus columnas se llaman distinto en cada DF:
clave_ventas = None
clave_marketing = None
if clave_comun is None and (clave_ventas is None or clave_marketing is None):
    print("No se encontró una clave común por nombre.")
    print("Opciones:")
    print("   a) Renombrá una columna para que coincida en ambos DataFrames (ej.: 'id_cliente').")
    print("   b) Definí manualmente las variables 'clave_ventas' y 'clave_marketing' más arriba.")
    print("      Ejemplo: clave_ventas='id_cliente'  |  clave_marketing='cliente_id'")
else:
    # ---------------------------
    # 3) Determinar las columnas de unión y calcular cardinalidad REAL
    # ---------------------------
    if clave_comun is not None:
        left_on = [clave_comun]
        right_on = [clave_comun]
        clave_label = clave_comun
    else:
        left_on = [clave_ventas]
        right_on = [clave_marketing]
        clave_label = f"{clave_ventas} (ventas) ↔ {clave_marketing} (marketing)"

    def hay_duplicados(df, cols):
        return df.duplicated(subset=cols, keep=False).any()

    dup_left = hay_duplicados(ventas_clean, left_on)
    dup_right = hay_duplicados(marketing_clean, right_on)

    if not dup_left and not dup_right:
        validate_card = "1:1"
    elif not dup_left and dup_right:
        validate_card = "1:m"
    elif dup_left and not dup_right:
        validate_card = "m:1"
    else:
        validate_card = "m:m"

    print("Clave de unión:", clave_label)
    print("Cardinalidad detectada:", validate_card)

    # ---------------------------
    # 4) Hacer el MERGE (LEFT JOIN)
    # ---------------------------
    ventas_marketing = pd.merge(
        left=ventas_clean,
        right=marketing_clean,
        how="left",
        left_on=left_on,
        right_on=right_on,
        sort=False,
        suffixes=("_ven", "_mkt"),
        copy=True,
        indicator=True,
        validate=validate_card
    )

    # Diagnóstico básico del resultado
    print("\nOrigen de filas según '_merge':")
    display(ventas_marketing['_merge'].value_counts(dropna=False).to_frame('conteo'))

    print("\nPrimeras filas del DataFrame unificado:")
    display(ventas_marketing.head())

    # ---------------------------
    # 5) Resumen por CAMPAÑA / CANAL (si existen esas columnas)
    # ---------------------------
    # Asegurar 'ingreso' = precio * cantidad si no existe
    vm = ventas_marketing.copy()
    if "ingreso" not in vm.columns and {"precio", "cantidad"}.issubset(vm.columns):
        vm = vm.assign(ingreso = vm["precio"] * vm["cantidad"])

    # Detectar posibles columnas de campaña/canal por nombres comunes
    def hallar_col(df, patrones):
        for c in df.columns:
            if any(p in c.lower() for p in patrones):
                return c
        return None

    camp_col  = hallar_col(vm, ["campaña", "campana", "id_campaña", "id_campana", "id_campanha", "campaign"])
    canal_col = hallar_col(vm, ["canal", "utm_source", "fuente", "source"])

    if camp_col and "ingreso" in vm.columns:
        resumen_camp = (
            vm.groupby(by=camp_col, dropna=False, as_index=False)
              .agg(
                  ingreso_total=('ingreso', 'sum'),
                  ventas=('ingreso', 'size')
              )
              .sort_values(by='ingreso_total', ascending=False, na_position='last', ignore_index=True)
        )
        print(f"\nIngreso total por campaña ({camp_col}):")
        display(resumen_camp.head(20))
    else:
        print("\nNo se encontró columna de campaña o no está 'ingreso' para resumir.")

    if canal_col and "ingreso" in vm.columns:
        resumen_canal = (
            vm.groupby(by=canal_col, dropna=False, as_index=False)
              .agg(
                  ingreso_total=('ingreso', 'sum'),
                  ventas=('ingreso', 'size')
              )
              .sort_values(by='ingreso_total', ascending=False, na_position='last', ignore_index=True)
        )
        print(f"\nIngreso total por canal ({canal_col}):")
        display(resumen_canal.head(20))
    else:
        print("No se encontró columna de canal o no está 'ingreso' para resumir.")
# Out:
# Clave de unión: producto
# Cardinalidad detectada: m:m
#
# Origen de filas según '_merge':
#             conteo
# _merge
# both          9000
# left_only        0
# right_only       0
# Primeras filas del DataFrame unificado:
#    id_venta           producto  precio  cantidad fecha_venta   categoria  \
# 0       792  Cuadro Decorativo   69.94         5  2024-01-02  Decoración
# 1       792  Cuadro Decorativo   69.94         5  2024-01-02  Decoración
# 2       792  Cuadro Decorativo   69.94         5  2024-01-02  Decoración
# 3       811    Lámpara De Mesa  105.10         5  2024-01-02  Decoración
# 4       811    Lámpara De Mesa  105.10         5  2024-01-02  Decoración
#
#    id_campanha  canal  costo fecha_inicio  fecha_fin _merge
# 0            1   Rrss   5.27   2024-04-27 2024-06-04   both
# 1           31  Email   5.28   2024-08-15 2024-09-12   both
# 2           61     Tv   5.30   2024-11-05 2024-12-23   both
# 3           32  Email   5.54   2024-03-28 2024-04-20   both
# 4            2   Rrss   5.88   2024-05-30 2024-06-29   both
# Ingreso total por campaña (id_campanha):
#     id_campanha  ingreso_total  ventas
# 0             2       82276.38     176
# 1            32       82276.38     176
# 2            62       82276.38     176
# 3            77       74175.58     143
# 4            47       74175.58     143
# 5            17       74175.58     143
# 6            26       72562.89     135
# 7            56       72562.89     135
# 8            86       72562.89     135
# 9            19       59607.31     117
# 10           49       59607.31     117
# 11           79       59607.31     117
# 12            1        54297.6     100
# 13           31        54297.6     100
# 14           61        54297.6     100
# 15           81       54132.44     101
# 16           51       54132.44     101
# 17           21       54132.44     101
# 18            3       52115.45     100
# 19           33       52115.45     100
# Ingreso total por canal (canal):
#    canal  ingreso_total  ventas
# 0  Email     1467093.52    3000
# 1   Rrss     1467093.52    3000
# 2     Tv     1467093.52    3000
